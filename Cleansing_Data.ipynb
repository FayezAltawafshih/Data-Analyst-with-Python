# %% [markdown]
# <a href="https://colab.research.google.com/github/FayezAltawafshih/Data-Analyst-with-Python/blob/main/Cleansing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import pandas as pd

# %%
import pandas as pd

# %%
# import csv

# %%
df = pd.read_csv('/content/sample_data/Cleaning Data.csv')

# %%
df
# Out:
#                 Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0     DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1   Saud Shakeel (PAK)  2022-2024  11*    20   3  1108  208*  65.17   2371
# 2       AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 3      RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 4      GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                 ...        ...  ...   ...  ..   ...   ...    ...    ...
# 62    KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 63   GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 64   WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 65     SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 66    DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7   626   6
# ...

# %%
# Rename multible columns in a list

# %%
df = df.rename(columns={'Mat':'Matches','No':'Not_Outs','HS':'Highest_Inns_Score','BF':'Balls_Faced','SR':'Batting_Strike_Rate',})

# %%
df.head()
# Out:
#                Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 0    DG Bradman (AUS)  1928-1948      52    80  10  6996                334
# 1  Saud Shakeel (PAK)  2022-2024     11*    20   3  1108               208*
# 2      AC Voges (AUS)  2015-2016      20    31   7  1485               269*
# 3     RG Pollock (SA)  1963-1970      23    41   4  2256                274
# 4     GA Headley (WI)  1930-1954      22    40   4  2190               270*
#
#      Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s
# 0  99.94       9800+                58.60   29  13  7  626   6
# 1  65.17        2371                46.73    3   6  -  121   1
# 2  61.87        2667                55.68    5   4  2  186   5
# 3  60.97       1707+                54.48    7  11  1  246  11
# 4  60.83        416+                56.00   10   5  2  104   1

# %%
# Check Null - Values

# %%
df.isnull().any()
# Out:
# Player                 False
# Span                   False
# Matches                False
# Inns                   False
# NO                     False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced             True
# Batting_Strike_Rate     True
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# dtype: bool

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#              Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 10   ED Weekes (WI)  1948-1958      48    81   5  4455                207
# 18  CL Walcott (WI)  1948-1960      44    74   7  3798                220
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s
# 10  58.61         NaN                  NaN   15  19  6  258   2
# 18  56.68         NaN                  NaN   15  14  1  107  11

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
df['Batting_Strike_Rate'] = df['Batting_Strike_Rate'].fillna(0)

# %%
df[df['Player']=='ED Weekes (WI)']
# Out:
#             Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 10  ED Weekes (WI)  1948-1958      48    81   5  4455                207
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s
# 10  58.61           0                  0.0   15  19  6  258   2

# %%
# drob duplicates

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 62    False
# 63    False
# 64    False
# 65    False
# 66    False
# Length: 67, dtype: bool

# %%
df[df['Player'].duplicated()==1]
# Out:
#              Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 5   GA Headley (WI)  1930-1954      22    40   4  2190               270*
# 13   GS Sobers (WI)  1954-1974      93   160  21  8032               365*
# 17   JB Hobbs (ENG)  1908-1930      61   102   7  5410                211
# 55    V Kohli (IND)  2011-2024     113   191  11  8848               254*
#
#       Ave Balls_Faced  Batting_Strike_Rate  100  50   0   4s  6s
# 5   60.83        416+                56.00   10   5   2  104   1
# 13  57.78       4063+                53.58   26  30  12  593  32
# 17  56.94       5363+                46.22   15  28   4  276   8
# 55  49.15       15924                55.56   29  30  14  991  26

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#                 Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 0     DG Bradman (AUS)  1928-1948      52    80  10  6996                334
# 1   Saud Shakeel (PAK)  2022-2024     11*    20   3  1108               208*
# 2       AC Voges (AUS)  2015-2016      20    31   7  1485               269*
# 3      RG Pollock (SA)  1963-1970      23    41   4  2256                274
# 4      GA Headley (WI)  1930-1954      22    40   4  2190               270*
# ..                 ...        ...     ...   ...  ..   ...                ...
# 62    KD Walters (AUS)  1965-1981      74   125  14  5357                250
# 63   GC Smith (ICC/SA)  2002-2014     117   205  13  9265                277
# 64   WH Ponsford (AUS)  1924-1934      29    48   4  2122                266
# 65     SJ McCabe (AUS)  1930-1938      39    62   5  2748                232
# 66    DR Jardine (ENG)  1928-1934      22    33   6  1296                127
#
# ...

# %%
# split up span into start and End Date

# %%
df['Span'].str.split('-')
# Out:
# 0     [1928, 1948]
# 1     [2022, 2024]
# 2     [2015, 2016]
# 3     [1963, 1970]
# 4     [1930, 1954]
#           ...
# 62    [1965, 1981]
# 63    [2002, 2014]
# 64    [1924, 1934]
# 65    [1930, 1938]
# 66    [1928, 1934]
# Name: Span, Length: 63, dtype: object

# %%
df['Span'].str.split('-',expand=True)
# Out:
#        0     1
# 0   1928  1948
# 1   2022  2024
# 2   2015  2016
# 3   1963  1970
# 4   1930  1954
# ..   ...   ...
# 62  1965  1981
# 63  2002  2014
# 64  1924  1934
# 65  1930  1938
# 66  1928  1934
#
# [63 rows x 2 columns]

# %%
df['Span'].str.split('-',expand=True)[0]
# Out:
# 0     1928
# 1     2022
# 2     2015
# 3     1963
# 4     1930
#       ...
# 62    1965
# 63    2002
# 64    1924
# 65    1930
# 66    1928
# Name: 0, Length: 63, dtype: object

# %%
df['Rookie_Year'] = df['Span'].str.split('-',expand=True)[0]

# %%
df['Final_Year'] = df['Span'].str.split('-',expand=True)[1]

# %%
df
# Out:
#                 Player       Span Matches  Inns  NO  Runs Highest_Inns_Score  \
# 0     DG Bradman (AUS)  1928-1948      52    80  10  6996                334
# 1   Saud Shakeel (PAK)  2022-2024     11*    20   3  1108               208*
# 2       AC Voges (AUS)  2015-2016      20    31   7  1485               269*
# 3      RG Pollock (SA)  1963-1970      23    41   4  2256                274
# 4      GA Headley (WI)  1930-1954      22    40   4  2190               270*
# ..                 ...        ...     ...   ...  ..   ...                ...
# 62    KD Walters (AUS)  1965-1981      74   125  14  5357                250
# 63   GC Smith (ICC/SA)  2002-2014     117   205  13  9265                277
# 64   WH Ponsford (AUS)  1924-1934      29    48   4  2122                266
# 65     SJ McCabe (AUS)  1930-1938      39    62   5  2748                232
# 66    DR Jardine (ENG)  1928-1934      22    33   6  1296                127
#
# ...

# %%
# drop span columns

# %%
df.drop(['Span'],axis=1,inplace=True)

# %%
df
# Out:
#                 Player Matches  Inns  NO  Runs Highest_Inns_Score    Ave  \
# 0     DG Bradman (AUS)      52    80  10  6996                334  99.94
# 1   Saud Shakeel (PAK)     11*    20   3  1108               208*  65.17
# 2       AC Voges (AUS)      20    31   7  1485               269*  61.87
# 3      RG Pollock (SA)      23    41   4  2256                274  60.97
# 4      GA Headley (WI)      22    40   4  2190               270*  60.83
# ..                 ...     ...   ...  ..   ...                ...    ...
# 62    KD Walters (AUS)      74   125  14  5357                250  48.26
# 63   GC Smith (ICC/SA)     117   205  13  9265                277  48.25
# 64   WH Ponsford (AUS)      29    48   4  2122                266  48.22
# 65     SJ McCabe (AUS)      39    62   5  2748                232  48.21
# 66    DR Jardine (ENG)      22    33   6  1296                127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s Rookie_Year  \
# ...

# %%
df.head()
# Out:
#                Player Matches  Inns  NO  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman (AUS)      52    80  10  6996                334  99.94
# 1  Saud Shakeel (PAK)     11*    20   3  1108               208*  65.17
# 2      AC Voges (AUS)      20    31   7  1485               269*  61.87
# 3     RG Pollock (SA)      23    41   4  2256                274  60.97
# 4     GA Headley (WI)      22    40   4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year Final_Year
# 0       9800+                58.60   29  13  7  626   6        1928       1948
# 1        2371                46.73    3   6  -  121   1        2022       2024
# 2        2667                55.68    5   4  2  186   5        2015       2016
# 3       1707+                54.48    7  11  1  246  11        1963       1970
# 4        416+                56.00   10   5  2  104   1        1930       1954

# %%
# Split up the Country from the player

# %%
df['Player'].str.split('(',expand=True)
# Out:
#                 0        1
# 0     DG Bradman      AUS)
# 1   Saud Shakeel      PAK)
# 2       AC Voges      AUS)
# 3     RG Pollock       SA)
# 4     GA Headley       WI)
# ..            ...      ...
# 62    KD Walters      AUS)
# 63      GC Smith   ICC/SA)
# 64   WH Ponsford      AUS)
# 65     SJ McCabe      AUS)
# 66    DR Jardine      ENG)
#
# [63 rows x 2 columns]

# %%
df['Country'] = df['Player'].str.split('(',expand=True)[1]

# %%
df['Country'] = df['Country'].str.replace(')','')

# %%
df['Country']
# Out:
# 0        AUS
# 1        PAK
# 2        AUS
# 3         SA
# 4         WI
#        ...
# 62       AUS
# 63    ICC/SA
# 64       AUS
# 65       AUS
# 66       ENG
# Name: Country, Length: 63, dtype: object

# %%
df['Player']
# Out:
# 0       DG Bradman (AUS)
# 1     Saud Shakeel (PAK)
# 2         AC Voges (AUS)
# 3        RG Pollock (SA)
# 4        GA Headley (WI)
#              ...
# 62      KD Walters (AUS)
# 63     GC Smith (ICC/SA)
# 64     WH Ponsford (AUS)
# 65       SJ McCabe (AUS)
# 66      DR Jardine (ENG)
# Name: Player, Length: 63, dtype: object

# %%
df['Player'] = df['Player'].str.split('(',expand=True)[0]

# %%
df.head()
# Out:
#           Player Matches  Inns  NO  Runs Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80  10  6996                334  99.94
# 1  Saud Shakeel      11*    20   3  1108               208*  65.17
# 2      AC Voges       20    31   7  1485               269*  61.87
# 3    RG Pollock       23    41   4  2256                274  60.97
# 4    GA Headley       22    40   4  2190               270*  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6        1928
# 1        2371                46.73    3   6  -  121   1        2022
# 2        2667                55.68    5   4  2  186   5        2015
# 3       1707+                54.48    7  11  1  246  11        1963
# 4        416+                56.00   10   5  2  104   1        1930
#
#   Final_Year Country
# 0       1948     AUS
# 1       2024     PAK
# 2       2016     AUS
# 3       1970      SA
# 4       1954      WI

# %%
# Change Datatypes

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score      object
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
df['Highest_Inns_Score'].str.split(pat='*').str[0]
# Out:
# 0     334
# 1     208
# 2     269
# 3     274
# 4     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'] = df['Highest_Inns_Score'].str.split(pat='*').str[0]

# %%
df['Highest_Inns_Score']
# Out:
# 0     334
# 1     208
# 2     269
# 3     274
# 4     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_Inns_Score, Length: 63, dtype: object

# %%
df['Highest_Inns_Score'].astype('int')
# Out:
# 0     334
# 1     208
# 2     269
# 3     274
# 4     270
#      ...
# 62    250
# 63    277
# 64    266
# 65    232
# 66    127
# Name: Highest_Inns_Score, Length: 63, dtype: int64

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year             object
# Final_Year              object
# Country                 object
# dtype: object

# %%
# SEE IF YOU CAN FIX Rookie Year and Final Year

# %%
df = df.astype({'Rookie_Year':'int','Final_Year':'int'})

# %%
df.astype({'Rookie_Year':'int','Final_Year':'int'})
# Out:
#            Player Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 0     DG Bradman       52    80  10  6996                 334  99.94
# 1   Saud Shakeel      11*    20   3  1108                 208  65.17
# 2       AC Voges       20    31   7  1485                 269  61.87
# 3     RG Pollock       23    41   4  2256                 274  60.97
# 4     GA Headley       22    40   4  2190                 270  60.83
# ..            ...     ...   ...  ..   ...                 ...    ...
# 62    KD Walters       74   125  14  5357                 250  48.26
# 63      GC Smith      117   205  13  9265                 277  48.25
# 64   WH Ponsford       29    48   4  2122                 266  48.22
# 65     SJ McCabe       39    62   5  2748                 232  48.21
# 66    DR Jardine       22    33   6  1296                 127  48.00
#
#    Balls_Faced  Batting_Strike_Rate  100  50   0    4s  6s  Rookie_Year  \
# ...

# %%
df.dtypes
# Out:
# Player                  object
# Matches                 object
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df.head()
# Out:
#           Player Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 0    DG Bradman       52    80  10  6996                 334  99.94
# 1  Saud Shakeel      11*    20   3  1108                 208  65.17
# 2      AC Voges       20    31   7  1485                 269  61.87
# 3    RG Pollock       23    41   4  2256                 274  60.97
# 4    GA Headley       22    40   4  2190                 270  60.83
#
#   Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 0       9800+                58.60   29  13  7  626   6         1928
# 1        2371                46.73    3   6  -  121   1         2022
# 2        2667                55.68    5   4  2  186   5         2015
# 3       1707+                54.48    7  11  1  246  11         1963
# 4        416+                56.00   10   5  2  104   1         1930
#
#    Final_Year Country
# 0        1948     AUS
# 1        2024     PAK
# 2        2016     AUS
# 3        1970      SA
# 4        1954      WI

# %%
df['Matches'] = df['Matches'].str.split(pat='*').str[0]

# %%
df['Matches'] = df['Matches'].astype('int')

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].str.split(pat='+').str[0]

# %%
df[df['Balls_Faced'].isna()==1]
# Out:
#          Player  Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 10   ED Weekes        48    81   5  4455                 207  58.61
# 18  CL Walcott        44    74   7  3798                 220  56.68
#
#    Balls_Faced  Batting_Strike_Rate  100  50  0   4s  6s  Rookie_Year  \
# 10         NaN                  0.0   15  19  6  258   2         1948
# 18         NaN                  0.0   15  14  1  107  11         1948
#
#     Final_Year Country
# 10        1958      WI
# 18        1960      WI

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)

# %%
pd.set_option('display.max_rows',None)
df
# Out:
#                Player  Matches  Inns  NO   Runs  Highest_Inns_Score    Ave  \
# 0         DG Bradman        52    80  10   6996                 334  99.94
# 1       Saud Shakeel        11    20   3   1108                 208  65.17
# 2           AC Voges        20    31   7   1485                 269  61.87
# 3         RG Pollock        23    41   4   2256                 274  60.97
# 4         GA Headley        22    40   4   2190                 270  60.83
# 6        H Sutcliffe        54    84   9   4555                 194  60.73
# 7          E Paynter        20    31   5   1540                 243  59.23
# 8      KF Barrington        82   131  15   6806                 256  58.67
# 9           HC Brook        16    26   1   1466                 186  58.64
# 10         ED Weekes        48    81   5   4455                 207  58.61
# 11        WR Hammond        85   140  16   7249                 336  58.45
# ...

# %%
df = df.drop(56,axis=0)

# %%
df
# Out:
#                Player  Matches  Inns  NO   Runs  Highest_Inns_Score    Ave  \
# 0         DG Bradman        52    80  10   6996                 334  99.94
# 1       Saud Shakeel        11    20   3   1108                 208  65.17
# 2           AC Voges        20    31   7   1485                 269  61.87
# 3         RG Pollock        23    41   4   2256                 274  60.97
# 4         GA Headley        22    40   4   2190                 270  60.83
# 6        H Sutcliffe        54    84   9   4555                 194  60.73
# 7          E Paynter        20    31   5   1540                 243  59.23
# 8      KF Barrington        82   131  15   6806                 256  58.67
# 9           HC Brook        16    26   1   1466                 186  58.64
# 10         ED Weekes        48    81   5   4455                 207  58.61
# 11        WR Hammond        85   140  16   7249                 336  58.45
# ...

# %%
df.isnull().any()
# Out:
# Player                 False
# Matches                False
# Inns                   False
# NO                     False
# Runs                   False
# Highest_Inns_Score     False
# Ave                    False
# Balls_Faced            False
# Batting_Strike_Rate    False
# 100                    False
# 50                     False
# 0                      False
# 4s                     False
# 6s                     False
# Rookie_Year            False
# Final_Year             False
# Country                False
# dtype: bool

# %%
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced             object
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['Balls_Faced'] = df['Balls_Faced'].fillna(0)
df['Balls_Faced'] = df['Balls_Faced'].astype('int')
df.dtypes
# Out:
# Player                  object
# Matches                  int64
# Inns                     int64
# NO                       int64
# Runs                     int64
# Highest_Inns_Score       int64
# Ave                    float64
# Balls_Faced              int64
# Batting_Strike_Rate    float64
# 100                      int64
# 50                       int64
# 0                       object
# 4s                       int64
# 6s                       int64
# Rookie_Year              int64
# Final_Year               int64
# Country                 object
# dtype: object

# %%
df['career_length'] = df['Final_Year'] - df['Rookie_Year']
df
# Out:
#                Player  Matches  Inns  NO   Runs  Highest_Inns_Score    Ave  \
# 0         DG Bradman        52    80  10   6996                 334  99.94
# 1       Saud Shakeel        11    20   3   1108                 208  65.17
# 2           AC Voges        20    31   7   1485                 269  61.87
# 3         RG Pollock        23    41   4   2256                 274  60.97
# 4         GA Headley        22    40   4   2190                 270  60.83
# 6        H Sutcliffe        54    84   9   4555                 194  60.73
# 7          E Paynter        20    31   5   1540                 243  59.23
# 8      KF Barrington        82   131  15   6806                 256  58.67
# 9           HC Brook        16    26   1   1466                 186  58.64
# 10         ED Weekes        48    81   5   4455                 207  58.61
# 11        WR Hammond        85   140  16   7249                 336  58.45
# ...

# %%
df['career_length'].mean()
# Out:
# 13.064516129032258

# %%
df[df['career_length']>10]['Batting_Strike_Rate']
# Out:
# 0     58.60
# 4     56.00
# 6     34.59
# 8     42.42
# 11    38.07
# 12    53.58
# 14    54.19
# 15    53.50
# 16    46.22
# 18     0.00
# 19    39.34
# 20    45.97
# 22    51.41
# 25    51.53
# 26    63.88
# 27    54.04
# 28    60.51
# 29    45.99
# 30    42.51
# 31    52.39
# 32    52.12
# 33    58.72
# 37    43.31
# 38    43.35
# 39    48.64
# 40    60.10
# 41    54.51
# 42    41.09
# 43    56.70
# 45    69.77
# 46    38.81
# 47    51.45
# 48    54.02
# 50    40.16
# 51    30.04
# 52    82.23
# 54    55.56
# 58    29.11
# 59     0.00
# 60    46.92
# 61    43.74
# 62    49.16
# 63    59.67
# Name: Batting_Strike_Rate, dtype: float64

# %%
df[df['career_length']>10]['Batting_Strike_Rate'].mean()
# Out:
# 47.76558139534884

# %%
df[df['Rookie_Year']<1960].count()
# Out:
# Player                 23
# Matches                23
# Inns                   23
# NO                     23
# Runs                   23
# Highest_Inns_Score     23
# Ave                    23
# Balls_Faced            23
# Batting_Strike_Rate    23
# 100                    23
# 50                     23
# 0                      23
# 4s                     23
# 6s                     23
# Rookie_Year            23
# Final_Year             23
# Country                23
# career_length          23
# dtype: int64

# %%
df[df['Rookie_Year']<1960]
# Out:
#              Player  Matches  Inns  NO  Runs  Highest_Inns_Score    Ave  \
# 0       DG Bradman        52    80  10  6996                 334  99.94
# 4       GA Headley        22    40   4  2190                 270  60.83
# 6      H Sutcliffe        54    84   9  4555                 194  60.73
# 7        E Paynter        20    31   5  1540                 243  59.23
# 8    KF Barrington        82   131  15  6806                 256  58.67
# 10       ED Weekes        48    81   5  4455                 207  58.61
# 11      WR Hammond        85   140  16  7249                 336  58.45
# 12       GS Sobers        93   160  21  8032                 365  57.78
# 16        JB Hobbs        61   102   7  5410                 211  56.94
# 18      CL Walcott        44    74   7  3798                 220  56.68
# 19        L Hutton        79   138  15  6971                 364  56.67
# 21    GE Tyldesley        14    20   2   990                 122  55.00
# ...

# %%
df.groupby('Country')['Highest_Inns_Score'].mean()
# Out:
# Country
# AUS        246.333333
# ENG        222.846154
# ICC/IND    294.500000
# ICC/PAK    329.000000
# ICC/SA     250.500000
# ICC/WI     400.000000
# IND        241.250000
# NZ         220.500000
# PAK        247.800000
# SA         223.200000
# SL         308.000000
# WI         250.000000
# ZIM        232.000000
# Name: Highest_Inns_Score, dtype: float64

# %%
df.groupby('Country')['Highest_Inns_Score'].max()
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# ICC/SA     277
# ICC/WI     400
# IND        254
# NZ         251
# PAK        313
# SA         278
# SL         374
# WI         365
# ZIM        232
# Name: Highest_Inns_Score, dtype: int64

# %%
df.groupby('Country')['Highest_Inns_Score'].mean().to_frame('Highinncountry').reset_index().sort_values('Highinncountry')
# Out:
#     Country  Highinncountry
# 7        NZ      220.500000
# 1       ENG      222.846154
# 9        SA      223.200000
# 12      ZIM      232.000000
# 6       IND      241.250000
# 0       AUS      246.333333
# 8       PAK      247.800000
# 11       WI      250.000000
# 4    ICC/SA      250.500000
# 2   ICC/IND      294.500000
# 10       SL      308.000000
# 3   ICC/PAK      329.000000
# 5    ICC/WI      400.000000

# %%
df.groupby('Country')['Highest_Inns_Score'].mean().to_frame('Highinncountry').reset_index().sort_values('Highinncountry',ascending=False)
# Out:
#     Country  Highinncountry
# 5    ICC/WI      400.000000
# 3   ICC/PAK      329.000000
# 10       SL      308.000000
# 2   ICC/IND      294.500000
# 4    ICC/SA      250.500000
# 11       WI      250.000000
# 8       PAK      247.800000
# 0       AUS      246.333333
# 6       IND      241.250000
# 12      ZIM      232.000000
# 9        SA      223.200000
# 1       ENG      222.846154
# 7        NZ      220.500000
